# %% [markdown]
# <a href="https://colab.research.google.com/github/VigneshGondrawar/numpy1/blob/main/numpy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.arange(6).reshape(2,3)
print(a,type(a))
print("Dimension of a=",a.ndim)
print("Shape of a=",a.shape)
print("size of a", a.size)
# Out:
# [[0 1 2]
#  [3 4 5]] <class 'numpy.ndarray'>
# Dimension of a= 2
# Shape of a= (2, 3)
# size of a 6
